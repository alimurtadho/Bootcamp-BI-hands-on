# %%
import pandas as pd
# import os
# import sys

# %%
# sys.path.insert(0, os.path.abspath('../dataset/Sample Superstore.xls'))

# %%
#import csv
read_file = pd.read_excel('/Users/newuser/ali/project/binar/notebook/dataset/Dataset Superstore Orders - BI Engineer.xlsx')

# %%
# print(read_file)
read_file
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        1.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID        Country             City       State  Postal Code  \
# 0       CG-12520  United States        Henderson    Kentucky      42420.0
# ...

# %%
data = read_file

# %%
#show information dataset
data.info() #
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Row ID       9994 non-null   float64
#  1   Order ID     9994 non-null   object
#  2   Order Date   9994 non-null   datetime64[ns]
#  3   Ship Date    9994 non-null   datetime64[ns]
#  4   Ship Mode    9994 non-null   object
#  5   Customer ID  9994 non-null   object
#  6   Country      9994 non-null   object
#  7   City         9994 non-null   object
#  8   State        9994 non-null   object
#  9   Postal Code  9994 non-null   float64
#  10  Region       9994 non-null   object
#  11  Product ID   9990 non-null   object
#  12  Sales        9994 non-null   float64
#  13  Quantity     9994 non-null   float64
#  14  Discount     9994 non-null   float64
#  15  Profit       9994 non-null   float64
# dtypes: datetime64[ns](2), float64(6), object(8)
# memory usage: 1.2+ MB

# %%
#show data 5 teratas
data.head(10)
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0     1.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1     2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2     3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3     4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4     5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 5     6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 6     7.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 7     8.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 8     9.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
# 9    10.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class    BH-11710
#
#          Country             City       State  Postal Code Region  \
# ...

# %%
#show data desc 
data.tail(15)
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 9979  9980.0  US-2016-103674 2016-12-06 2016-12-10  Standard Class
# 9980  9981.0  US-2015-151435 2015-09-06 2015-09-09    Second Class
# 9981  9982.0  CA-2017-163566 2017-08-03 2017-08-06     First Class
# 9982  9983.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9983  9984.0  US-2016-157728 2016-09-22 2016-09-28  Standard Class
# 9984  9985.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9985  9986.0  CA-2015-100251 2015-05-17 2015-05-23  Standard Class
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9988  9989.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# ...

# %%
#calculate data row and coloumn
data.shape
# Out:
# (9994, 16)

# %%
data["Profit"].median()
# Out:
# 8.6665

# %%
#show statistical number data type
data.describe()
# Out:
#             Row ID   Postal Code         Sales     Quantity     Discount  \
# count  9994.000000   9994.000000   9994.000000  9994.000000  9994.000000
# mean   4997.500000  55190.379428    229.858001     3.789574     0.156203
# std    2885.163629  32063.693350    623.245101     2.225110     0.206452
# min       1.000000   1040.000000      0.444000     1.000000     0.000000
# 25%    2499.250000  23223.000000     17.280000     2.000000     0.000000
# 50%    4997.500000  56430.500000     54.490000     3.000000     0.200000
# 75%    7495.750000  90008.000000    209.940000     5.000000     0.200000
# max    9994.000000  99301.000000  22638.480000    14.000000     0.800000
#
#             Profit
# count  9994.000000
# mean     28.656896
# std     234.260108
# min   -6599.978000
# 25%       1.728750
# 50%       8.666500
# 75%      29.364000
# max    8399.976000

# %%
#statistical serderna all colloumn
data.describe(include = "all")
# Out:
# /var/folders/mw/7trd4drs0ls3k8h_w746_wpm0000gr/T/ipykernel_2385/492029716.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = "all")
# /var/folders/mw/7trd4drs0ls3k8h_w746_wpm0000gr/T/ipykernel_2385/492029716.py:2: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data.describe(include = "all")
#              Row ID        Order ID           Order Date            Ship Date  \
# count   9994.000000            9994                 9994                 9994
# unique          NaN            5009                 1237                 1334
# ...

# %%
#show data uninque / distinct
data["Customer ID"].unique()
# Out:
# array(['CG-12520', 'DV-13045', 'SO-20335', 'BH-11710', 'AA-10480',
#        'IM-15070', 'HP-14815', 'PK-19075', 'AG-10270', 'ZD-21925',
#        'KB-16585', 'SF-20065', 'EB-13870', 'EH-13945', 'TB-21520',
#        'MA-17560', 'GH-14485', 'SN-20710', 'LC-16930', 'RA-19885',
#        'ES-14080', 'ON-18715', 'PO-18865', 'LH-16900', 'DP-13000',
#        'JM-15265', 'TB-21055', 'KM-16720', 'PS-18970', 'BS-11590',
#        'KD-16270', 'HM-14980', 'JE-15745', 'KB-16600', 'SC-20770',
#        'DN-13690', 'JC-16105', 'CS-12400', 'PG-18895', 'GM-14455',
#        'JS-15685', 'KB-16315', 'RB-19705', 'PN-18775', 'KD-16345',
#        'ER-13855', 'RB-19465', 'GZ-14470', 'LC-16870', 'JM-15250',
#        'PA-19060', 'CV-12805', 'CL-12565', 'RC-19960', 'DK-13090',
#        'GG-14650', 'SC-20725', 'AD-10180', 'PF-19165', 'TS-21610',
#        'LS-16975', 'DW-13585', 'LC-16885', 'JD-15895', 'SH-19975',
#        'SG-20080', 'HA-14920', 'MG-17680', 'JE-16165', 'TW-21025',
# ...

# %%
# data["Order ID"] = ["9994"]
data.loc[data['Order ID'] == "CA-2017-100111"]
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 6090  6091.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6091  6092.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6092  6093.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6093  6094.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6094  6095.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6095  6096.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6096  6097.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6097  6098.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6098  6099.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6099  6100.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6100  6101.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6101  6102.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# 6102  6103.0  CA-2017-100111 2017-09-20 2017-09-26  Standard Class
# ...

# %%
# # check missing value
# data = pd.DataFrame(data)

# using isnull() function
data.isnull()
# Out:
#       Row ID  Order ID  Order Date  Ship Date  Ship Mode  Customer ID  \
# 0      False     False       False      False      False        False
# 1      False     False       False      False      False        False
# 2      False     False       False      False      False        False
# 3      False     False       False      False      False        False
# 4      False     False       False      False      False        False
# ...      ...       ...         ...        ...        ...          ...
# 9989   False     False       False      False      False        False
# 9990   False     False       False      False      False        False
# 9991   False     False       False      False      False        False
# 9992   False     False       False      False      False        False
# 9993   False     False       False      False      False        False
#
#       Country   City  State  Postal Code  Region  Product ID  Sales  Quantity  \
# ...

# %%
# data.loc[data['Product ID'] == "NaN"]
data.columns[data.isnull().any()].tolist()
# Out:
# ['Product ID']

# %%
#check data insull with resume jumlah
data.isnull().sum()
# Out:
# Row ID         0
# Order ID       0
# Order Date     0
# Ship Date      0
# Ship Mode      0
# Customer ID    0
# Country        0
# City           0
# State          0
# Postal Code    0
# Region         0
# Product ID     4
# Sales          0
# Quantity       0
# Discount       0
# Profit         0
# dtype: int64

# %%
data_test = pd.read_csv('/Users/newuser/ali/project/kampus merdeka/repo_dibimbing/dataset/Data latihan sql/Sample - Store - Orders.csv')

# %%
#check data duplicat
data_test.duplicated().sum()
# Out:
# 1

# %%
# data_categories.duplicated().sum()

# %%
#show data is duplicate
data_test[data_test.duplicated(keep=False)]
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
# 3406  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID   Category Sub-Category  \
# 3405   East  FUR-CH-10002965  Furniture       Chairs
# 3406   East  FUR-CH-10002965  Furniture       Chairs
#
#                                            Product Name    Sales  Quantity  \
# 3405  Global Leather Highback Executive Chair with P...  281.372         2
# 3406  Global Leather Highback Executive Chair with P...  281.372         2
#
#       Discount   Profit
# 3405       0.3 -12.0588
# 3406       0.3 -12.0588

# %%
data_test.loc[data_test['Order ID'] == "US-2014-150119"]
# Out:
#             Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 3405  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
# 3406  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
# 3407  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
# 3408  US-2014-150119  04/23/2014  04/27/2014  Standard Class    LB-16795
#
#        Customer Name      Segment        Country      City State  Postal Code  \
# 3405  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3406  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3407  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
# 3408  Laurel Beltran  Home Office  United States  Columbus  Ohio        43229
#
#      Region       Product ID         Category Sub-Category  \
# 3405   East  FUR-CH-10002965        Furniture       Chairs
# 3406   East  FUR-CH-10002965        Furniture       Chairs
# ...

# %%
#select data with name coloumns
selected_data= data[["Order ID","Ship Mode","Region"]]

# %%
selected_data.duplicated().sum()
# Out:
# 4985

# %%
data
# Out:
#       Row ID        Order ID Order Date  Ship Date       Ship Mode  \
# 0        1.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1        2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4        5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# ...      ...             ...        ...        ...             ...
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9991  9992.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9992  9993.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      Customer ID        Country             City       State  Postal Code  \
# 0       CG-12520  United States        Henderson    Kentucky      42420.0
# ...

# %%
#select data with slicing
selectd_slice = data.iloc[:, 2:9]
selectd_slice
# Out:
#      Order Date  Ship Date       Ship Mode Customer ID        Country  \
# 0    2016-11-08 2016-11-11    Second Class    CG-12520  United States
# 1    2016-11-08 2016-11-11    Second Class    CG-12520  United States
# 2    2016-06-12 2016-06-16    Second Class    DV-13045  United States
# 3    2015-10-11 2015-10-18  Standard Class    SO-20335  United States
# 4    2015-10-11 2015-10-18  Standard Class    SO-20335  United States
# ...         ...        ...             ...         ...            ...
# 9989 2014-01-21 2014-01-23    Second Class    TB-21400  United States
# 9990 2017-02-26 2017-03-03  Standard Class    DB-13060  United States
# 9991 2017-02-26 2017-03-03  Standard Class    DB-13060  United States
# 9992 2017-02-26 2017-03-03  Standard Class    DB-13060  United States
# 9993 2017-05-04 2017-05-09    Second Class    CC-12220  United States
#
#                  City       State
# 0           Henderson    Kentucky
# 1           Henderson    Kentucky
# ...

# %%
#filtering
filter_ship_mode = selectd_slice["Ship Mode"] = "Second Class"

# %%
filter_ship_mode
# Out:
# 'Second Class'

# %%
# removing null values to avoid errors
data.dropna(inplace = True)

# %%
data.isnull().sum()
# Out:
# Row ID         0
# Order ID       0
# Order Date     0
# Ship Date      0
# Ship Mode      0
# Customer ID    0
# Country        0
# City           0
# State          0
# Postal Code    0
# Region         0
# Product ID     0
# Sales          0
# Quantity       0
# Discount       0
# Profit         0
# dtype: int64

# %%
#check data
data = data.loc[:,~data.columns.duplicated()]

# %%
data
# Out:
#       row_id        order_id order_date  ship_date       ship_mode  \
# 0        1.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2        3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3        4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 5        6.0  CA-2014-115812 2014-06-09 2014-06-14  Standard Class
# 12      13.0  CA-2017-114412 2017-04-15 2017-04-20  Standard Class
# ...      ...             ...        ...        ...             ...
# 9986  9987.0  CA-2016-125794 2016-09-29 2016-10-03  Standard Class
# 9987  9988.0  CA-2017-163629 2017-11-17 2017-11-21  Standard Class
# 9989  9990.0  CA-2014-110422 2014-01-21 2014-01-23    Second Class
# 9990  9991.0  CA-2017-121258 2017-02-26 2017-03-03  Standard Class
# 9993  9994.0  CA-2017-119914 2017-05-04 2017-05-09    Second Class
#
#      customer_id        country             city           state  postal_code  \
# 0       CG-12520  United States        Henderson        Kentucky      42420.0
# ...

# %%
data_test.drop_duplicates(subset=['Order ID'], inplace=True)

# %%
data_test.duplicated().sum()
# Out:
# 0

# %%
#pandas sql
from pandasql import sqldf

# %%
q="""
SELECT 
DISTINCT Region 
FROM data;
"""
pysqldf = lambda q: sqldf(q, globals())
a_df = pysqldf(q)
print(a_df)
# Out:
#     Region
# 0    South
# 1     West
# 2  Central
# 3     East
# 4   Southn

# %%
region = data['region'].unique()

# Create the pandas DataFrame
contoh_df = pd.DataFrame(region, columns=['region'])
print(contoh_df )
# Out:
#     region
# 0    South
# 1     West
# 2  Central
# 3     East
# 4   Southn

# %%
query = """
select *
from data

order by 'Order ID' asc
limit 5
"""
pysqldf = lambda q: sqldf(query, globals())
df = pysqldf(query)
df
# Out:
#          Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0  CA-2016-152156  11/08/2016  11/11/2016    Second Class    CG-12520
# 1  CA-2016-138688  06/12/2016  06/16/2016    Second Class    DV-13045
# 2  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3  CA-2014-115812  06/09/2014  06/14/2014  Standard Class    BH-11710
# 4  CA-2017-114412  04/15/2017  04/20/2017  Standard Class    AA-10480
#
#      Customer Name    Segment        Country             City           State  \
# 0      Claire Gute   Consumer  United States        Henderson        Kentucky
# 1  Darrin Van Huff  Corporate  United States      Los Angeles      California
# 2   Sean O'Donnell   Consumer  United States  Fort Lauderdale         Florida
# 3  Brosina Hoffman   Consumer  United States      Los Angeles      California
# 4     Andrew Allen   Consumer  United States          Concord  North Carolina
#
#    Postal Code Region       Product ID         Category Sub-Category  \
# ...

# %%
#lower case coloumn
data_test.columns = map(str.lower, data_test.columns)
data_test.columns = data_test.columns.str.replace(' ', '_').str.replace('-', '_')

# %%
#lower case coloumn
data.columns = map(str.lower, data.columns)
data.columns = data.columns.str.replace(' ', '_').str.replace('-', '_')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5006 entries, 0 to 9993
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   row_id       5006 non-null   float64
#  1   order_id     5006 non-null   object
#  2   order_date   5006 non-null   datetime64[ns]
#  3   ship_date    5006 non-null   datetime64[ns]
#  4   ship_mode    5006 non-null   object
#  5   customer_id  5006 non-null   object
#  6   country      5006 non-null   object
#  7   city         5006 non-null   object
#  8   state        5006 non-null   object
#  9   postal_code  5006 non-null   float64
#  10  region       5006 non-null   object
#  11  product_id   5006 non-null   object
#  12  sales        5006 non-null   float64
#  13  quantity     5006 non-null   float64
#  14  discount     5006 non-null   float64
#  15  profit       5006 non-null   float64
# dtypes: datetime64[ns](2), float64(6), object(8)
# memory usage: 793.9+ KB

# %%
data_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5009 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       5009 non-null   object
#  1   order_date     5009 non-null   object
#  2   ship_date      5009 non-null   object
#  3   ship_mode      5009 non-null   object
#  4   customer_id    5009 non-null   object
#  5   customer_name  5009 non-null   object
#  6   segment        5009 non-null   object
#  7   country        5009 non-null   object
#  8   city           5009 non-null   object
#  9   state          5009 non-null   object
#  10  postal_code    5009 non-null   int64
#  11  region         5009 non-null   object
#  12  product_id     5009 non-null   object
#  13  category       5009 non-null   object
#  14  sub_category   5009 non-null   object
#  15  product_name   5009 non-null   object
#  16  sales          5009 non-null   float64
# ...

# %%
read_file.duplicated().sum()
# Out:
# 1

# %%
# initialize list of lists
data_frame = [['tom', 10], ['nick', 15], ['juli', 14]]
 
# Create the pandas DataFrame
df_contoh = pd.DataFrame(data_frame, columns=['Name', 'Age'])
 
# print dataframe.
print(df_contoh)
# Out:
#    Name  Age
# 0   tom   10
# 1  nick   15
# 2  juli   14

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5009 entries, 0 to 9993
# Data columns (total 20 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   order_id       5009 non-null   object
#  1   order_date     5009 non-null   object
#  2   ship_date      5009 non-null   object
#  3   ship_mode      5009 non-null   object
#  4   customer_id    5009 non-null   object
#  5   customer_name  5009 non-null   object
#  6   segment        5009 non-null   object
#  7   country        5009 non-null   object
#  8   city           5009 non-null   object
#  9   state          5009 non-null   object
#  10  postal_code    5009 non-null   int64
#  11  region         5009 non-null   object
#  12  product_id     5009 non-null   object
#  13  category       5009 non-null   object
#  14  sub_category   5009 non-null   object
#  15  product_name   5009 non-null   object
#  16  sales          5009 non-null   float64
# ...

# %%
print(f"Distinct entries: {len(data.groupby(['Order Date', 'Sales']))}")
# Out:
# Distinct entries: 9601

# %%
data['year'] = data['order_date'].dt.year
print(data['year'])

# %%
data['year'].unique()
# Out:
# array([2016, 2015, 2014, 2017])

# %%
data['year'].value_counts()
# Out:
# 2019    4273
# 2018    3175
# 2017    2520
# 2016    2441
# Name: year, dtype: int64

# %%
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Text, String, DateTime

# %%
conection=create_engine('postgresql://username:passwrod@host:port/database')

# %%
conn = conection.connect()

# %%
# engine = create_engine('postgresql://username:password@localhost:5432/mydatabase')
data.to_sql( 'your table', 
        con=conection,
        schema='schema',
        if_exists='replace',
        index=True,
        index_label = 'index',
        method='multi')
# Out:
# 9994

# %%
read_data_pg = pd.read_sql("""
select * from binar.superstore_order_ingest
limit 5
""", 
con=conection)
read_data_pg
# Out:
#    index  row_id        order_id order_date  ship_date       ship_mode  \
# 0      0     1.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 1      1     2.0  CA-2016-152156 2016-11-08 2016-11-11    Second Class
# 2      2     3.0  CA-2016-138688 2016-06-12 2016-06-16    Second Class
# 3      3     4.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
# 4      4     5.0  US-2015-108966 2015-10-11 2015-10-18  Standard Class
#
#   customer_id        country             city       state  postal_code region  \
# 0    CG-12520  United States        Henderson    Kentucky      42420.0  South
# 1    CG-12520  United States        Henderson    Kentucky      42420.0  South
# 2    DV-13045  United States      Los Angeles  California      90036.0   West
# 3    SO-20335  United States  Fort Lauderdale     Florida      33311.0  South
# 4    SO-20335  United States  Fort Lauderdale     Florida      33311.0  South
#
#         product_id     sales  quantity  discount    profit
# ...
