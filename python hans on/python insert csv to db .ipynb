# %%
import pandas as pd
import sqlalchemy
from pandasql import sqldf
from datetime import datetime, timedelta, date
from sqlalchemy import create_engine
from sqlalchemy.types import Integer, Text, String, DateTime
# import psycopg2

# %%
df = pd.read_excel('/Users/newuser/ali/project/binar/facil BIE/python/dataset/Sample Superstore.xlsx')
df.head()
# Out:
#   Order Date        Order ID         Category Sub-Category  \
# 0 2018-11-08  CA-2018-152156        Furniture    Bookcases
# 1 2018-11-08  CA-2018-152156        Furniture       Chairs
# 2 2018-06-12  CA-2018-138688  Office Supplies       Labels
# 3 2017-10-11  US-2017-108966        Furniture       Tables
# 4 2017-10-11  US-2017-108966  Office Supplies      Storage
#
#                                         Product Name    Segment  \
# 0                  Bush Somerset Collection Bookcase   Consumer
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   Consumer
# 2  Self-Adhesive Address Labels for Typewriters b...  Corporate
# 3      Bretford CR4500 Series Slim Rectangular Table   Consumer
# 4                     Eldon Fold 'N Roll Cart System   Consumer
#
#          Country Region       State             City  Postal Code  \
# 0  United States  South    Kentucky        Henderson      42420.0
# 1  United States  South    Kentucky        Henderson      42420.0
# ...

# %%
df.columns = map(str.lower, df.columns) #stadarization lower header 
df.columns = df.columns.str.replace(' ', '_').str.replace('→_', '') #

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80231 entries, 0 to 80230
# Data columns (total 50 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   id                                   80231 non-null  float64
#  1   order_type                           80231 non-null  object
#  2   order_invoice_number                 80231 non-null  object
#  3   order_amount                         80231 non-null  float64
#  4   order_initial_amount                 76509 non-null  float64
#  5   promo_value                          76509 non-null  float64
#  6   promo_detail                         8968 non-null   object
#  7   vat_real                             80231 non-null  float64
#  8   order_receipt_name                   75262 non-null  object
#  9   order_created_at                     80231 non-null  object
#  10  order_slip_verified_at               80223 non-null  object
# ...

# %%
conection='postgresql://postgres:123qwe@localhost:5432/binar_dl'

# %%
db_2 = create_engine(conection)
conn_2 = db_2.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# File ~/ali/project/binar/notebook/venv/lib/python3.9/site-packages/sqlalchemy/engine/base.py:3280, in Engine._wrap_pool_connect(self, fn, connection)
#    3279 try:
# -> 3280     return fn()
#    3281 except dialect.dbapi.Error as e:
#
# File ~/ali/project/binar/notebook/venv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:310, in Pool.connect(self)
#     303 """Return a DBAPI connection from the pool.
#     304
#     305 The connection is instrumented such that when its
#    (...)
#     308
#     309 """
# --> 310 return _ConnectionFairy._checkout(self)
#
# File ~/ali/project/binar/notebook/venv/lib/python3.9/site-packages/sqlalchemy/pool/base.py:868, in _ConnectionFairy._checkout(cls, pool, threadconns, fairy)
#     867 if not fairy:
# --> 868     fairy = _ConnectionRecord.checkout(pool)
#     870     fairy._pool = pool
#
# ...

# %%
# insert dataframe to postgres spesfici schema dl 
df.to_sql('bootcamp_mart', con=conn_2, schema='gsheet', if_exists='replace',index=True,index_label='index',method='multi')
conn = psycopg2.connect(conection
                        )
conn.autocommit = True
cursor = conn.cursor()
